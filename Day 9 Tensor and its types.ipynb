# %% [markdown]
# # Scalar

# %%
import numpy as np

# %%
X = np.array(10)
y = np.array(200)

# %%
y.ndim
# Out:
# 0

# %% [markdown]
# # 1D Tensor

# %%
x = np.array([10,20,30,40])

# %%
print(x)
# Out:
# [10 20 30 40]

# %%
x.ndim
# Out:
# 1

# %%
table = np.array([[1,3,4],[4,5,6],[7,8,9]])

# %%
table
# Out:
# array([[1, 3, 4],
#        [4, 5, 6],
#        [7, 8, 9]])

# %%
table.ndim
# Out:
# 2

# %% [markdown]
# # 3D tensor

# %%
ddd = np.array([[[10,20],[100,200]],[[10,20],[100,200]],[[10,20],[100,200]]])

# %%
ddd
# Out:
# array([[[ 10,  20],
#         [100, 200]],
#
#        [[ 10,  20],
#         [100, 200]],
#
#        [[ 10,  20],
#         [100, 200]]])

# %%
ddd.ndim
# Out:
# 3
