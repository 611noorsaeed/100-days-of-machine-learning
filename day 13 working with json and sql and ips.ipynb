# %%
# compnay resquest:

https://api.themoviedb.org/3/movie/top_rated?api_key=390e76286265f7638bb6b19d86474639&language=en-US
    
# my api key
390e76286265f7638bb6b19d86474639

# %% [markdown]
# # Working With APIs

# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=390e76286265f7638bb6b19d86474639&language=en-US')

# %%
mydf = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity']]

# %%
mydf.head()
# Out:
#        id                     title  \
# 0     238             The Godfather
# 1     278  The Shawshank Redemption
# 2  772071          Cuando Sea Joven
# 3     240     The Godfather Part II
# 4     424          Schindler's List
#
#                                             overview  popularity
# 0  Spanning the years 1945 to 1955, a chronicle o...     109.741
# 1  Framed in the 1940s for the double murder of h...      83.656
# 2  70-year-old Malena gets a second chance at lif...      38.713
# 3  In the continuing saga of the Corleone crime f...      61.500
# 4  The true story of how businessman Oskar Schind...      52.323

# %%
df1 = pd.DataFrame()
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=390e76286265f7638bb6b19d86474639&language=en-US'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df1 = df1.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:159, in HTTPConnection._new_conn(self)
#     158 try:
# --> 159     conn = connection.create_connection(
#     160         (self._dns_host, self.port), self.timeout, **extra_kw
#     161     )
#     163 except SocketTimeout:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:61, in create_connection(address, timeout, source_address, socket_options)
#      59 family = allowed_gai_family()
# ---> 61 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# ...
